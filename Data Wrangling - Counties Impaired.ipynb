# %%
import pandas as pd

# %%
df = pd.read_excel ('sasExport0DE6.xlsx')

# %%
df.shape
# Out:
# (756, 3)

# %%
df.head(10)
# Out:
#    YEAR    County   Total
# 0  2011       NaN  9383.0
# 1  2011    ALBANY   245.0
# 2  2011    ALBANY     8.0
# 3  2011    ALBANY    93.0
# 4  2011    ALBANY   144.0
# 5  2011  ALLEGANY    60.0
# 6  2011  ALLEGANY     NaN
# 7  2011  ALLEGANY    27.0
# 8  2011  ALLEGANY    33.0
# 9  2011     BRONX   164.0

# %%
df.County.value_counts()
# Out:
# ALBANY         12
# GENESEE        12
# KINGS          12
# OTSEGO         12
# MONTGOMERY     12
#                ..
# TOMPKINS       12
# CATTARAUGUS    12
# SARATOGA       12
# HERKIMER       12
# UNKNOWN         9
# Name: County, Length: 63, dtype: int64

# %%
# df['County'].isnull().sum()
# Out:
# 3

# %%
better_df = df.loc[df['County'] != 'UNKNOWN']

# %%
better_df = better_df[better_df['County'].notna()]

# %%
better_df.shape
# Out:
# (744, 3)

# %%
better_df.head()
# Out:
#    YEAR    County  Total
# 1  2011    ALBANY  245.0
# 2  2011    ALBANY    8.0
# 3  2011    ALBANY   93.0
# 4  2011    ALBANY  144.0
# 5  2011  ALLEGANY   60.0

# %%
totals = better_df.iloc[0:745:4,:]

# %%
totals.tail(50)
# Out:
#      YEAR        County  Total
# 553  2013      DELAWARE   48.0
# 557  2013      DUTCHESS  203.0
# 561  2013          ERIE  623.0
# 565  2013         ESSEX   45.0
# 569  2013      FRANKLIN   43.0
# 573  2013        FULTON   45.0
# 577  2013       GENESEE   69.0
# 581  2013        GREENE   60.0
# 585  2013      HAMILTON    8.0
# 589  2013      HERKIMER   55.0
# 593  2013     JEFFERSON  109.0
# 597  2013         KINGS  407.0
# 601  2013         LEWIS   26.0
# 605  2013    LIVINGSTON   50.0
# 609  2013       MADISON   50.0
# 613  2013        MONROE  562.0
# 617  2013    MONTGOMERY   50.0
# 621  2013        NASSAU  626.0
# 625  2013      NEW YORK  258.0
# 629  2013       NIAGARA  158.0
# 633  2013        ONEIDA  159.0
# 637  2013      ONONDAGA  338.0
# 641  2013       ONTARIO   84.0
# 645  2013        ORANGE  323.0
# 649  2013       ORLEANS   37.0
# 653  2013        OSWEGO   90.0
# 657  2013        OTSEGO   57.0
# 661  2013        PUTNAM   97.0
# 665  2013        QUEENS  437.0
# ...

# %%
totals.isnull().sum()
# Out:
# YEAR      0
# County    0
# Total     0
# dtype: int64

# %%
totals.to_excel('maybe_fixed.xlsx')

# %%
totals_grouped = totals.groupby(['County']).Total.sum().reset_index()

# %%
totals_grouped.head()
# Out:
#         County  Total
# 0       ALBANY  736.0
# 1     ALLEGANY  148.0
# 2        BRONX  600.0
# 3       BROOME  449.0
# 4  CATTARAUGUS  225.0

# %%
def div_by_tree(x):
    return int(x/3)

# %%
totals_grouped['Total'] = totals_grouped['Total'].apply(div_by_tree)

# %%
totals_grouped.head()
# Out:
#         County  Total
# 0       ALBANY    245
# 1     ALLEGANY     49
# 2        BRONX    200
# 3       BROOME    149
# 4  CATTARAUGUS     75

# %%
totals_grouped.to_excel('population_dui.xlsx')
